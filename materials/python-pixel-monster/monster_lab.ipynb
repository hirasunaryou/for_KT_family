# %% [markdown]
# # ドット絵モンスター工房
# ここに自分の画像と実験を作ろう。
# 説明サイト: https://hirasunaryou.github.io/for_KT_family/study/programming/python-pixel-monster/
# monster_tools.pyを同じフォルダに置く。

# %% [markdown]
# ## MISSION 1: 1ピクセルから、モンスター誕生

# %%
# 仕様を読んで作る。設計図や骨組みはサイトからコピーしてOK。

# %% [markdown]
# 予想:
#
# 目で確かめたこと:
#
# 改造したこと:

# %% [markdown]
# ## MISSION 2: 色違いと、おばけを作る

# %%
# 仕様を読んで作る。設計図や骨組みはサイトからコピーしてOK。

# %% [markdown]
# 予想:
#
# 目で確かめたこと:
#
# 改造したこと:

# %% [markdown]
# ## MISSION 3: 反転・切り抜き・拡大を比べる

# %%
# 仕様を読んで作る。設計図や骨組みはサイトからコピーしてOK。

# %% [markdown]
# 予想:
#
# 目で確かめたこと:
#
# 改造したこと:

# %% [markdown]
# ## MISSION 4: 自分のモンスターチーム

# %%
# 仕様を読んで作る。設計図や骨組みはサイトからコピーしてOK。

# %% [markdown]
# 予想:
#
# 目で確かめたこと:
#
# 改造したこと:

# %% [markdown]
# ## MISSION 5: モンスター自動生成工場

# %%
# 仕様を読んで作る。設計図や骨組みはサイトからコピーしてOK。

# %% [markdown]
# 予想:
#
# 目で確かめたこと:
#
# 改造したこと:

# %% [markdown]
# ## MISSION 6: まばたきGIFで、命を吹き込む

# %%
# 仕様を読んで作る。設計図や骨組みはサイトからコピーしてOK。

# %% [markdown]
# 予想:
#
# 目で確かめたこと:
#
# 改造したこと:
