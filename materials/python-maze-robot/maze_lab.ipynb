# %% [markdown]
# # 迷路メーカー＆脱出ロボット
# 自分のコードと実験メモを書くNotebook。
# 説明サイト: https://hirasunaryou.github.io/for_KT_family/study/programming/python-maze-robot/
# maze_tools.pyを同じフォルダへ。

# %% [markdown]
# ## MISSION 1: 文字の地図が、迷路になる

# %%
# 仕様から自分で書こう。必要ならサイトの骨組みを使う。

# %% [markdown]
# 予想:
#
# 確かめたこと:
#
# 改造したこと:

# %% [markdown]
# ## MISSION 2: 壁をすり抜けないプレイヤー

# %%
# 仕様から自分で書こう。必要ならサイトの骨組みを使う。

# %% [markdown]
# 予想:
#
# 確かめたこと:
#
# 改造したこと:

# %% [markdown]
# ## MISSION 3: 足跡を覚えるロボット

# %%
# 仕様から自分で書こう。必要ならサイトの骨組みを使う。

# %% [markdown]
# 予想:
#
# 確かめたこと:
#
# 改造したこと:

# %% [markdown]
# ## MISSION 4: 最短経路が光る探索

# %%
# 仕様から自分で書こう。必要ならサイトの骨組みを使う。

# %% [markdown]
# 予想:
#
# 確かめたこと:
#
# 改造したこと:

# %% [markdown]
# ## MISSION 5: 遊べる迷路だけを自動生成

# %%
# 仕様から自分で書こう。必要ならサイトの骨組みを使う。

# %% [markdown]
# 予想:
#
# 確かめたこと:
#
# 改造したこと:

# %% [markdown]
# ## MISSION 6: 追跡ロボットから脱出せよ

# %%
# 仕様から自分で書こう。必要ならサイトの骨組みを使う。

# %% [markdown]
# 予想:
#
# 確かめたこと:
#
# 改造したこと:
