# %% [markdown]
# # サイコロ研究所
# このNotebookに自分のコードを書こう。dice_tools.pyを同じフォルダに置く。
# 説明サイト: https://hirasunaryou.github.io/for_KT_family/study/programming/python-dice-jupyter/

# %%
# 準備ページの最初の1行をここに書こう

# %% [markdown]
# ## MISSION 1: 実況つき・サイコロ記録マシン
# 本編の制作課題に挑戦。必要な命令はサイトの道具カードで確認しよう。予想・実測・気づきもここに残す。

# %%
# ここに自分のコードを書く

# %% [markdown]
# ## MISSION 2: 連続記録を見つけるハンター
# 本編の制作課題に挑戦。必要な命令はサイトの道具カードで確認しよう。予想・実測・気づきもここに残す。

# %%
# ここに自分のコードを書く

# %% [markdown]
# ## MISSION 3: 1万回の集計と出目ランキング
# 本編の制作課題に挑戦。必要な命令はサイトの道具カードで確認しよう。予想・実測・気づきもここに残す。

# %%
# ここに自分のコードを書く

# %% [markdown]
# ## MISSION 4: 実験を自動で20回くり返す
# 本編の制作課題に挑戦。必要な命令はサイトの道具カードで確認しよう。予想・実測・気づきもここに残す。

# %%
# ここに自分のコードを書く

# %% [markdown]
# ## MISSION 5: イカサマ設計図と理論値
# 本編の制作課題に挑戦。必要な命令はサイトの道具カードで確認しよう。予想・実測・気づきもここに残す。

# %%
# ここに自分のコードを書く

# %% [markdown]
# ## MISSION 6: 調査と推理を関数にする
# 本編の制作課題に挑戦。必要な命令はサイトの道具カードで確認しよう。予想・実測・気づきもここに残す。

# %%
# ここに自分のコードを書く

# %% [markdown]
# ## MISSION 7: ルールを調整して、友達に挑戦状
# 本編の制作課題に挑戦。必要な命令はサイトの道具カードで確認しよう。予想・実測・気づきもここに残す。

# %%
# ここに自分のコードを書く
