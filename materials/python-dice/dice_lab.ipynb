# %% [markdown]
# # サイコロ研究所
# このNotebookに自分のコードを書こう。dice_tools.pyを同じフォルダに置く。
# 説明サイト: https://hirasunaryou.github.io/for_KT_family/study/programming/python-dice-jupyter/

# %%
# 準備ページの最初の1行をここに書こう

# %% [markdown]
# ## MISSION 1: 100回しゃべるロボット
# 説明サイトを読み、下のセルに書こう。必要ならコードセルを追加。

# %%
# ここに自分のコードを書く

# %% [markdown]
# ## MISSION 2: サイコロ連打マシン
# 説明サイトを読み、下のセルに書こう。必要ならコードセルを追加。

# %%
# ここに自分のコードを書く

# %% [markdown]
# ## MISSION 3: 1万回の実験
# 説明サイトを読み、下のセルに書こう。必要ならコードセルを追加。

# %%
# ここに自分のコードを書く

# %% [markdown]
# ## MISSION 4: 確率を割合で調べる
# 説明サイトを読み、下のセルに書こう。必要ならコードセルを追加。

# %%
# ここに自分のコードを書く

# %% [markdown]
# ## MISSION 5: イカサマを仕込め
# 説明サイトを読み、下のセルに書こう。必要ならコードセルを追加。

# %%
# ここに自分のコードを書く

# %% [markdown]
# ## MISSION 6: 自分の関数
# 説明サイトを読み、下のセルに書こう。必要ならコードセルを追加。

# %%
# ここに自分のコードを書く

# %% [markdown]
# ## MISSION 7: 友達に渡せるゲーム
# 説明サイトを読み、下のセルに書こう。必要ならコードセルを追加。

# %%
# ここに自分のコードを書く
